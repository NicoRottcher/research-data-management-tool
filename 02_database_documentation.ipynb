# %% [markdown]
# # Documentation
# The database consists of multiple tables with multiple columns. For each table and column, in the database there is a comment stored, explaining in more detail the meaning and use of it.

# %% [markdown]
# ### I have a column name what does it mean?

# %%
import evaluation.utils.db as db

col_name = 'E_WE__VvsRHE'

doc_table = db.query_sql(''' SELECT * FROM documentation_columns WHERE name_column = %s''',
                         params=[col_name],
                         index_col=['name_column', 'name_table']
                        )
display(doc_table.style.set_properties(**{
    'text-align': 'left',
    'white-space': 'pre-wrap',
}))
# Out:
# <style type="text/css">
# #T_fe303_row0_col0, #T_fe303_row0_col1, #T_fe303_row0_col2, #T_fe303_row0_col3, #T_fe303_row0_col4, #T_fe303_row0_col5, #T_fe303_row0_col6, #T_fe303_row1_col0, #T_fe303_row1_col1, #T_fe303_row1_col2, #T_fe303_row1_col3, #T_fe303_row1_col4, #T_fe303_row1_col5, #T_fe303_row1_col6 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_fe303">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe303_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_fe303_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_fe303_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_fe303_level0_col3" class="col_heading level0 col3" >table_type</th>
#       <th id="T_fe303_level0_col4" class="col_heading level0 col4" >data_type</th>
#       <th id="T_fe303_level0_col5" class="col_heading level0 col5" >max_length</th>
#       <th id="T_fe303_level0_col6" class="col_heading level0 col6" >precision</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="index_name level1" >name_table</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe303_level0_row0" class="row_heading level0 row0" rowspan="2">E_WE__VvsRHE</th>
#       <th id="T_fe303_level1_row0" class="row_heading level1 row0" >data_ec_analysis</th>
#       <td id="T_fe303_row0_col0" class="data row0 col0" >calculated</td>
#       <td id="T_fe303_row0_col1" class="data row0 col1" >potential corrected for RE to RHE using E_RE__VvsRHE and iR insitu and post-compensated  by exp_ec.R_u__ohm and exp_ec.iR_corr_in_situ__percent</td>
#       <td id="T_fe303_row0_col2" class="data row0 col2" >$E$ / V vs. RHE</td>
#       <td id="T_fe303_row0_col3" class="data row0 col3" >VIEW</td>
#       <td id="T_fe303_row0_col4" class="data row0 col4" >b'double'</td>
#       <td id="T_fe303_row0_col5" class="data row0 col5" >22</td>
#       <td id="T_fe303_row0_col6" class="data row0 col6" >0</td>
#     </tr>
#     <tr>
#       <th id="T_fe303_level1_row1" class="row_heading level1 row1" >data_ec_polcurve_analysis</th>
#       <td id="T_fe303_row1_col0" class="data row1 col0" >calculated</td>
#       <td id="T_fe303_row1_col1" class="data row1 col1" >working electrode potential compensated for iR-drop</td>
#       <td id="T_fe303_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_fe303_row1_col3" class="data row1 col3" >VIEW</td>
#       <td id="T_fe303_row1_col4" class="data row1 col4" >b'double'</td>
#       <td id="T_fe303_row1_col5" class="data row1 col5" >22</td>
#       <td id="T_fe303_row1_col6" class="data row1 col6" >0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### The value of the column is calculated by a view. What is the definition of the View?
# Simple calculations are performed by SQL database upon request. The definition of these caluclated columns can be found in the create view statement.

# %%
import evaluation.utils.db as db
import sqlparse

name_view = 'data_ec_analysis'

sql_create_view = db.get_create_view(name_view)
print(sqlparse.format(sql_create_view, reindent=True, keyword_case='upper'))
# Out:
# CREATE ALGORITHM=UNDEFINED DEFINER=`nico`@`%` SQL SECURITY DEFINER VIEW `data_ec_analysis` AS
# SELECT `d`.`id_exp_sfc` AS `id_exp_sfc`,
#        `d`.`id_data_ec` AS `id_data_ec`,
#        `d`.`t__s` AS `t__s`,
#        if((`d`.`Timestamp` IS NULL),(`e`.`t_start__timestamp` + interval `d`.`t__s` SECOND),`d`.`Timestamp`) AS `Timestamp`,
#        `d`.`E_WE_raw__VvsRE` AS `E_WE_raw__VvsRE`,
#        `d`.`Delta_E_WE_uncomp__V` AS `Delta_E_WE_uncomp__V`,
#        `d`.`E_Signal__VvsRE` AS `E_Signal__VvsRE`,
#        `d`.`I__A` AS `I__A`,
#        `d`.`overload` AS `overload`,
#        `d`.`cycle` AS `cycle`,
#        if(((`e`.`ec_R_u__ohm` * `e`.`ec_iR_corr_in_situ__percent`) <> 0),((`d`.`E_WE_raw__VvsRE` + `e`.`ec_E_RE__VvsRHE`) - ((`d`.`I__A` * `e`.`ec_R_u__ohm`) * (1 - (`e`.`ec_iR_corr_in_situ__percent` / 100)))),NULL) AS `E_WE__VvsRHE`,
#        ((`d`.`E_WE_raw__VvsRE` + `e`.`ec_E_RE__VvsRHE`) + `d`.`Delta_E_WE_uncomp__V`) AS `E_WE_uncompensated__VvsRHE`,
#        (`d`.`E_WE_raw__VvsRE` + `e`.`ec_E_RE__VvsRHE`) AS `E_WE_raw__VvsRHE`,
#        ((`d`.`I__A` * 1000) / (`e`.`spots_spot_size__mm2` / 100)) AS `j__mA_cm2geo_spot_size`,
#        ((`d`.`I__A` * 1000) / (`e`.`fc_top_name_flow_cell_A_opening_ideal__mm2` / 100)) AS `j__mA_cm2geo_fc_top_cell_Aideal`,
#        ((`d`.`I__A` * 1000) / (`e`.`fc_top_name_flow_cell_A_opening_real__mm2` / 100)) AS `j__mA_cm2geo_fc_top_cell_Areal`,
#        ((`d`.`I__A` * 1000) / (`e`.`fc_top_id_sealing_A_opening__mm2` / 100)) AS `j__mA_cm2geo_fc_top_sealing`,
#        ((`d`.`I__A` * 1000) / (`e`.`fc_top_id_PTL_A_PTL__mm2` / 100)) AS `j__mA_cm2geo_fc_top_PTL`,
#        ((`d`.`I__A` * 1000) / (`e`.`fc_bottom_name_flow_cell_A_opening_ideal__mm2` / 100)) AS `j__mA_cm2geo_fc_bottom_cell_Aideal`,
#        ((`d`.`I__A` * 1000) / (`e`.`fc_bottom_name_flow_cell_A_opening_real__mm2` / 100)) AS `j__mA_cm2geo_fc_bottom_cell_Areal`,
#        ((`d`.`I__A` * 1000) / (`e`.`fc_bottom_id_sealing_A_opening__mm2` / 100)) AS `j__mA_cm2geo_fc_bottom_sealing`,
#        ((`d`.`I__A` * 1000) / (`e`.`fc_bottom_id_PTL_A_PTL__mm2` / 100)) AS `j__mA_cm2geo_fc_bottom_PTL`
# FROM (`data_ec` `d`
#       JOIN `exp_ec_expanded` `e`)
# WHERE (`d`.`id_exp_sfc` = `e`.`id_exp_sfc`)

# %% [markdown]
# ### I want to read documentation of all tables and columns

# %%
import evaluation.utils.db as db
from IPython.display import display, Markdown
doc_table = db.query_sql(''' SELECT * FROM documentation_tables''',
                         index_col=['name_table']
                        )
for name_table, row in doc_table.iterrows():
    doc_cols = db.query_sql(''' SELECT name_column, name_inserter, comment, name_axislabel__latex, data_type FROM documentation_columns WHERE name_table = %s''',
                            params=[name_table],
                         index_col=['name_column']
                        )
    display(Markdown(
    f"""### {name_table}
        Table type: {row.table_type}
        Comment: {row.comment_table}
    """))
    #display(doc_cols)
    display(doc_cols.style.set_properties(**{
    'text-align': 'left',
    'white-space': 'pre-wrap',
}))
# Out:
# ### ana_icpms_sfc_fitting
#         BASE TABLE
#         Stores results from sfc icpms fits as performed by Fit_SFC_ICP_MS_Dissolution.py
# <style type="text/css">
# #T_29821_row0_col0, #T_29821_row0_col1, #T_29821_row0_col2, #T_29821_row0_col3, #T_29821_row1_col0, #T_29821_row1_col1, #T_29821_row1_col2, #T_29821_row1_col3, #T_29821_row2_col0, #T_29821_row2_col1, #T_29821_row2_col2, #T_29821_row2_col3, #T_29821_row3_col0, #T_29821_row3_col1, #T_29821_row3_col2, #T_29821_row3_col3, #T_29821_row4_col0, #T_29821_row4_col1, #T_29821_row4_col2, #T_29821_row4_col3, #T_29821_row5_col0, #T_29821_row5_col1, #T_29821_row5_col2, #T_29821_row5_col3, #T_29821_row6_col0, #T_29821_row6_col1, #T_29821_row6_col2, #T_29821_row6_col3, #T_29821_row7_col0, #T_29821_row7_col1, #T_29821_row7_col2, #T_29821_row7_col3, #T_29821_row8_col0, #T_29821_row8_col1, #T_29821_row8_col2, #T_29821_row8_col3, #T_29821_row9_col0, #T_29821_row9_col1, #T_29821_row9_col2, #T_29821_row9_col3, #T_29821_row10_col0, #T_29821_row10_col1, #T_29821_row10_col2, #T_29821_row10_col3, #T_29821_row11_col0, #T_29821_row11_col1, #T_29821_row11_col2, #T_29821_row11_col3, #T_29821_row12_col0, #T_29821_row12_col1, #T_29821_row12_col2, #T_29821_row12_col3 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_29821">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29821_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_29821_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_29821_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_29821_level0_col3" class="col_heading level0 col3" >data_type</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29821_level0_row0" class="row_heading level0 row0" >file_path_plot_sfc_icpms_peakfit</th>
#       <td id="T_29821_row0_col0" class="data row0 col0" >hte_processor</td>
#       <td id="T_29821_row0_col1" class="data row0 col1" >path to the plot displaying raw data and the fit</td>
#       <td id="T_29821_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_29821_row0_col3" class="data row0 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_29821_level0_row1" class="row_heading level0 row1" >fitinput_background_correction</th>
#       <td id="T_29821_row1_col0" class="data row1 col0" >hte_processor</td>
#       <td id="T_29821_row1_col1" class="data row1 col1" >is background correction on fit performed?</td>
#       <td id="T_29821_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_29821_row1_col3" class="data row1 col3" >tinyint</td>
#     </tr>
#     <tr>
#       <th id="T_29821_level0_row2" class="row_heading level0 row2" >fitinput_datapoints_fit_single_peak</th>
#       <td id="T_29821_row2_col0" class="data row2 col0" >hte_processor</td>
#       <td id="T_29821_row2_col1" class="data row2 col1" >amount of datapoints to fit single icpms peak during fit routine</td>
#       <td id="T_29821_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_29821_row2_col3" class="data row2 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_29821_level0_row3" class="row_heading level0 row3" >fitinput_datapoints_peak_distance</th>
#       <td id="T_29821_row3_col0" class="data row3 col0" >hte_processor</td>
#       <td id="T_29821_row3_col1" class="data row3 col1" >amount of datapoints as minimum distance between peaks for auto detect during fit routine</td>
#       <td id="T_29821_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_29821_row3_col3" class="data row3 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_29821_level0_row4" class="row_heading level0 row4" >fitinput_prominence</th>
#       <td id="T_29821_row4_col0" class="data row4 col0" >hte_processor</td>
#       <td id="T_29821_row4_col1" class="data row4 col1" >prominence to auto detect the peaks during fit routine</td>
#       <td id="T_29821_row4_col2" class="data row4 col2" >None</td>
#       <td id="T_29821_row4_col3" class="data row4 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_29821_level0_row5" class="row_heading level0 row5" >id_exp_ec_dataset</th>
#       <td id="T_29821_row5_col0" class="data row5 col0" >hte_processor</td>
#       <td id="T_29821_row5_col1" class="data row5 col1" >dataset of ec experiments, can be one or multiple id_exp_sfc as defined by exp_ec_datasets_definer</td>
#       <td id="T_29821_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_29821_row5_col3" class="data row5 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_29821_level0_row6" class="row_heading level0 row6" >id_exp_icpms</th>
#       <td id="T_29821_row6_col0" class="data row6 col0" >hte_processor</td>
#       <td id="T_29821_row6_col1" class="data row6 col1" >index of icpms experiment</td>
#       <td id="T_29821_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_29821_row6_col3" class="data row6 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_29821_level0_row7" class="row_heading level0 row7" >id_fit</th>
#       <td id="T_29821_row7_col0" class="data row7 col0" >hte_processor</td>
#       <td id="T_29821_row7_col1" class="data row7 col1" >index of the processed fit. Default = 0, higher if multiple fits have been performed on the same data.</td>
#       <td id="T_29821_row7_col2" class="data row7 col2" >None</td>
#       <td id="T_29821_row7_col3" class="data row7 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_29821_level0_row8" class="row_heading level0 row8" >manual_peaks</th>
#       <td id="T_29821_row8_col0" class="data row8 col0" >hte_processor</td>
#       <td id="T_29821_row8_col1" class="data row8 col1" >manually added peaks during fit routine</td>
#       <td id="T_29821_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_29821_row8_col3" class="data row8 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_29821_level0_row9" class="row_heading level0 row9" >name_isotope_analyte</th>
#       <td id="T_29821_row9_col0" class="data row9 col0" >hte_processor</td>
#       <td id="T_29821_row9_col1" class="data row9 col1" >name of the analyte used as internalstandard</td>
#       <td id="T_29821_row9_col2" class="data row9 col2" >None</td>
#       <td id="T_29821_row9_col3" class="data row9 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_29821_level0_row10" class="row_heading level0 row10" >name_isotope_internalstandard</th>
#       <td id="T_29821_row10_col0" class="data row10 col0" >hte_processor</td>
#       <td id="T_29821_row10_col1" class="data row10 col1" >name of the isotope used as internalstandard</td>
#       <td id="T_29821_row10_col2" class="data row10 col2" >None</td>
#       <td id="T_29821_row10_col3" class="data row10 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_29821_level0_row11" class="row_heading level0 row11" >R2adj</th>
#       <td id="T_29821_row11_col0" class="data row11 col0" >hte_processor</td>
#       <td id="T_29821_row11_col1" class="data row11 col1" >adjusted R^2 value as goodness of fit</td>
#       <td id="T_29821_row11_col2" class="data row11 col2" >None</td>
#       <td id="T_29821_row11_col3" class="data row11 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_29821_level0_row12" class="row_heading level0 row12" >t_inserted__timestamp</th>
#       <td id="T_29821_row12_col0" class="data row12 col0" >hte_processor</td>
#       <td id="T_29821_row12_col1" class="data row12 col1" >timestamp of insertion of the data</td>
#       <td id="T_29821_row12_col2" class="data row12 col2" >None</td>
#       <td id="T_29821_row12_col3" class="data row12 col3" >datetime</td>
#     </tr>
#   </tbody>
# </table>
# ### ana_icpms_sfc_fitting_peaks
#         BASE TABLE
#         Stores details of peaks for fits in exp_icpms_sfc_peaks
# <style type="text/css">
# #T_fd924_row0_col0, #T_fd924_row0_col1, #T_fd924_row0_col2, #T_fd924_row0_col3, #T_fd924_row1_col0, #T_fd924_row1_col1, #T_fd924_row1_col2, #T_fd924_row1_col3, #T_fd924_row2_col0, #T_fd924_row2_col1, #T_fd924_row2_col2, #T_fd924_row2_col3, #T_fd924_row3_col0, #T_fd924_row3_col1, #T_fd924_row3_col2, #T_fd924_row3_col3, #T_fd924_row4_col0, #T_fd924_row4_col1, #T_fd924_row4_col2, #T_fd924_row4_col3, #T_fd924_row5_col0, #T_fd924_row5_col1, #T_fd924_row5_col2, #T_fd924_row5_col3, #T_fd924_row6_col0, #T_fd924_row6_col1, #T_fd924_row6_col2, #T_fd924_row6_col3, #T_fd924_row7_col0, #T_fd924_row7_col1, #T_fd924_row7_col2, #T_fd924_row7_col3, #T_fd924_row8_col0, #T_fd924_row8_col1, #T_fd924_row8_col2, #T_fd924_row8_col3, #T_fd924_row9_col0, #T_fd924_row9_col1, #T_fd924_row9_col2, #T_fd924_row9_col3, #T_fd924_row10_col0, #T_fd924_row10_col1, #T_fd924_row10_col2, #T_fd924_row10_col3, #T_fd924_row11_col0, #T_fd924_row11_col1, #T_fd924_row11_col2, #T_fd924_row11_col3, #T_fd924_row12_col0, #T_fd924_row12_col1, #T_fd924_row12_col2, #T_fd924_row12_col3, #T_fd924_row13_col0, #T_fd924_row13_col1, #T_fd924_row13_col2, #T_fd924_row13_col3, #T_fd924_row14_col0, #T_fd924_row14_col1, #T_fd924_row14_col2, #T_fd924_row14_col3, #T_fd924_row15_col0, #T_fd924_row15_col1, #T_fd924_row15_col2, #T_fd924_row15_col3, #T_fd924_row16_col0, #T_fd924_row16_col1, #T_fd924_row16_col2, #T_fd924_row16_col3, #T_fd924_row17_col0, #T_fd924_row17_col1, #T_fd924_row17_col2, #T_fd924_row17_col3, #T_fd924_row18_col0, #T_fd924_row18_col1, #T_fd924_row18_col2, #T_fd924_row18_col3, #T_fd924_row19_col0, #T_fd924_row19_col1, #T_fd924_row19_col2, #T_fd924_row19_col3, #T_fd924_row20_col0, #T_fd924_row20_col1, #T_fd924_row20_col2, #T_fd924_row20_col3 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_fd924">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd924_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_fd924_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_fd924_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_fd924_level0_col3" class="col_heading level0 col3" >data_type</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd924_level0_row0" class="row_heading level0 row0" >area__ng_cm2</th>
#       <td id="T_fd924_row0_col0" class="data row0 col0" >hte_processor</td>
#       <td id="T_fd924_row0_col1" class="data row0 col1" >fit parameter: area of the fitted peak</td>
#       <td id="T_fd924_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_fd924_row0_col3" class="data row0 col3" >double</td>
#     </tr>
#     <tr>
#       <th id="T_fd924_level0_row1" class="row_heading level0 row1" >area_error__ng_cm2</th>
#       <td id="T_fd924_row1_col0" class="data row1 col0" >hte_processor</td>
#       <td id="T_fd924_row1_col1" class="data row1 col1" >error of fit parameter: area of the fitted peak</td>
#       <td id="T_fd924_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_fd924_row1_col3" class="data row1 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_fd924_level0_row2" class="row_heading level0 row2" >fit_type</th>
#       <td id="T_fd924_row2_col0" class="data row2 col0" >hte_processor</td>
#       <td id="T_fd924_row2_col1" class="data row2 col1" >for each peak the fit parameter for single and sum are stored.
# single: fit of the peak just considering amounts of datapoints around the peak (exp_icpms_sfc_fitting.fitinput_datapoints_fit_single_peak or less if another peak is close)
# sum: fit parameters of the single peak (mode) within the fit of all peaks.</td>
#       <td id="T_fd924_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_fd924_row2_col3" class="data row2 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_fd924_level0_row3" class="row_heading level0 row3" >id_exp_ec_dataset</th>
#       <td id="T_fd924_row3_col0" class="data row3 col0" >hte_processor</td>
#       <td id="T_fd924_row3_col1" class="data row3 col1" >dataset of ec experiments, can be one or multiple id_exp_sfc as defined by exp_ec_datasets_definer</td>
#       <td id="T_fd924_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_fd924_row3_col3" class="data row3 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_fd924_level0_row4" class="row_heading level0 row4" >id_exp_icpms</th>
#       <td id="T_fd924_row4_col0" class="data row4 col0" >hte_processor</td>
#       <td id="T_fd924_row4_col1" class="data row4 col1" >index of icpms experiment</td>
#       <td id="T_fd924_row4_col2" class="data row4 col2" >None</td>
#       <td id="T_fd924_row4_col3" class="data row4 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_fd924_level0_row5" class="row_heading level0 row5" >id_fit</th>
#       <td id="T_fd924_row5_col0" class="data row5 col0" >hte_processor</td>
#       <td id="T_fd924_row5_col1" class="data row5 col1" >index of the processed fit. Default = 0, higher if multiple fits have been performed on the same data.</td>
#       <td id="T_fd924_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_fd924_row5_col3" class="data row5 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_fd924_level0_row6" class="row_heading level0 row6" >id_peak</th>
#       <td id="T_fd924_row6_col0" class="data row6 col0" >hte_processor</td>
#       <td id="T_fd924_row6_col1" class="data row6 col1" >id of the peak</td>
#       <td id="T_fd924_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_fd924_row6_col3" class="data row6 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_fd924_level0_row7" class="row_heading level0 row7" >ln_std</th>
#       <td id="T_fd924_row7_col0" class="data row7 col0" >hte_processor</td>
#       <td id="T_fd924_row7_col1" class="data row7 col1" >fit parameter: natural logarithm</td>
#       <td id="T_fd924_row7_col2" class="data row7 col2" >None</td>
#       <td id="T_fd924_row7_col3" class="data row7 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_fd924_level0_row8" class="row_heading level0 row8" >ln_std_error</th>
#       <td id="T_fd924_row8_col0" class="data row8 col0" >hte_processor</td>
#       <td id="T_fd924_row8_col1" class="data row8 col1" >error of fit parameter: natural logarithm</td>
#       <td id="T_fd924_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_fd924_row8_col3" class="data row8 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_fd924_level0_row9" class="row_heading level0 row9" >mode__s</th>
#       <td id="T_fd924_row9_col0" class="data row9 col0" >hte_processor</td>
#       <td id="T_fd924_row9_col1" class="data row9 col1" >time of the icpms peak</td>
#       <td id="T_fd924_row9_col2" class="data row9 col2" >None</td>
#       <td id="T_fd924_row9_col3" class="data row9 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_fd924_level0_row10" class="row_heading level0 row10" >mode_error__s</th>
#       <td id="T_fd924_row10_col0" class="data row10 col0" >hte_processor</td>
#       <td id="T_fd924_row10_col1" class="data row10 col1" >error in the time of icpms peak</td>
#       <td id="T_fd924_row10_col2" class="data row10 col2" >None</td>
#       <td id="T_fd924_row10_col3" class="data row10 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_fd924_level0_row11" class="row_heading level0 row11" >mode_potential__VvsRHE</th>
#       <td id="T_fd924_row11_col0" class="data row11 col0" >hte_processor</td>
#       <td id="T_fd924_row11_col1" class="data row11 col1" >correlated potential of the icpms peak</td>
#       <td id="T_fd924_row11_col2" class="data row11 col2" >None</td>
#       <td id="T_fd924_row11_col3" class="data row11 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_fd924_level0_row12" class="row_heading level0 row12" >mode_potential_error__VvsRHE</th>
#       <td id="T_fd924_ro
# ### ana_integrations
#         BASE TABLE
#         stores all integration data
# <style type="text/css">
# #T_f9fa5_row0_col0, #T_f9fa5_row0_col1, #T_f9fa5_row0_col2, #T_f9fa5_row0_col3, #T_f9fa5_row1_col0, #T_f9fa5_row1_col1, #T_f9fa5_row1_col2, #T_f9fa5_row1_col3, #T_f9fa5_row2_col0, #T_f9fa5_row2_col1, #T_f9fa5_row2_col2, #T_f9fa5_row2_col3, #T_f9fa5_row3_col0, #T_f9fa5_row3_col1, #T_f9fa5_row3_col2, #T_f9fa5_row3_col3, #T_f9fa5_row4_col0, #T_f9fa5_row4_col1, #T_f9fa5_row4_col2, #T_f9fa5_row4_col3, #T_f9fa5_row5_col0, #T_f9fa5_row5_col1, #T_f9fa5_row5_col2, #T_f9fa5_row5_col3, #T_f9fa5_row6_col0, #T_f9fa5_row6_col1, #T_f9fa5_row6_col2, #T_f9fa5_row6_col3, #T_f9fa5_row7_col0, #T_f9fa5_row7_col1, #T_f9fa5_row7_col2, #T_f9fa5_row7_col3, #T_f9fa5_row8_col0, #T_f9fa5_row8_col1, #T_f9fa5_row8_col2, #T_f9fa5_row8_col3, #T_f9fa5_row9_col0, #T_f9fa5_row9_col1, #T_f9fa5_row9_col2, #T_f9fa5_row9_col3, #T_f9fa5_row10_col0, #T_f9fa5_row10_col1, #T_f9fa5_row10_col2, #T_f9fa5_row10_col3, #T_f9fa5_row11_col0, #T_f9fa5_row11_col1, #T_f9fa5_row11_col2, #T_f9fa5_row11_col3, #T_f9fa5_row12_col0, #T_f9fa5_row12_col1, #T_f9fa5_row12_col2, #T_f9fa5_row12_col3 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_f9fa5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f9fa5_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_f9fa5_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_f9fa5_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_f9fa5_level0_col3" class="col_heading level0 col3" >data_type</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f9fa5_level0_row0" class="row_heading level0 row0" >area_integrated_simps</th>
#       <td id="T_f9fa5_row0_col0" class="data row0 col0" >hte_processor</td>
#       <td id="T_f9fa5_row0_col1" class="data row0 col1" >integrated area following Simpson''s rule using python module scipy </td>
#       <td id="T_f9fa5_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_f9fa5_row0_col3" class="data row0 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_f9fa5_level0_row1" class="row_heading level0 row1" >area_integrated_trapz</th>
#       <td id="T_f9fa5_row1_col0" class="data row1 col0" >hte_processor</td>
#       <td id="T_f9fa5_row1_col1" class="data row1 col1" >trapezoidal integrated area using python module numpy.trapz</td>
#       <td id="T_f9fa5_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_f9fa5_row1_col3" class="data row1 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_f9fa5_level0_row2" class="row_heading level0 row2" >auto_integration</th>
#       <td id="T_f9fa5_row2_col0" class="data row2 col0" >hte_processor</td>
#       <td id="T_f9fa5_row2_col1" class="data row2 col1" >integration points found by algorithm or manually changed by user</td>
#       <td id="T_f9fa5_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_f9fa5_row2_col3" class="data row2 col3" >tinyint</td>
#     </tr>
#     <tr>
#       <th id="T_f9fa5_level0_row3" class="row_heading level0 row3" >id_ana_integration</th>
#       <td id="T_f9fa5_row3_col0" class="data row3 col0" >hte_processor</td>
#       <td id="T_f9fa5_row3_col1" class="data row3 col1" >index of the integration analysis</td>
#       <td id="T_f9fa5_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_f9fa5_row3_col3" class="data row3 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_f9fa5_level0_row4" class="row_heading level0 row4" >id_data_integration_baseline</th>
#       <td id="T_f9fa5_row4_col0" class="data row4 col0" >hte_processor</td>
#       <td id="T_f9fa5_row4_col1" class="data row4 col1" >index of the data of the corresponding experiment (ICPMS) or dataset (EC) for the chosen baseline point</td>
#       <td id="T_f9fa5_row4_col2" class="data row4 col2" >None</td>
#       <td id="T_f9fa5_row4_col3" class="data row4 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_f9fa5_level0_row5" class="row_heading level0 row5" >id_data_integration_begin</th>
#       <td id="T_f9fa5_row5_col0" class="data row5 col0" >hte_processor</td>
#       <td id="T_f9fa5_row5_col1" class="data row5 col1" >index of the data of the corresponding experiment (ICPMS) or dataset (EC) for the bgeinning of integration</td>
#       <td id="T_f9fa5_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_f9fa5_row5_col3" class="data row5 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_f9fa5_level0_row6" class="row_heading level0 row6" >id_data_integration_end</th>
#       <td id="T_f9fa5_row6_col0" class="data row6 col0" >hte_processor</td>
#       <td id="T_f9fa5_row6_col1" class="data row6 col1" >index of the data of the corresponding experiment (ICPMS) or dataset (EC) for the end of integration</td>
#       <td id="T_f9fa5_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_f9fa5_row6_col3" class="data row6 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_f9fa5_level0_row7" class="row_heading level0 row7" >no_of_datapoints_avg</th>
#       <td id="T_f9fa5_row7_col0" class="data row7 col0" >hte_processor</td>
#       <td id="T_f9fa5_row7_col1" class="data row7 col1" >number of datapoints used to average baseline and end value and calculate the y offset</td>
#       <td id="T_f9fa5_row7_col2" class="data row7 col2" >None</td>
#       <td id="T_f9fa5_row7_col3" class="data row7 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_f9fa5_level0_row8" class="row_heading level0 row8" >no_of_datapoints_rolling</th>
#       <td id="T_f9fa5_row8_col0" class="data row8 col0" >hte_processor</td>
#       <td id="T_f9fa5_row8_col1" class="data row8 col1" >number of datapoints to smoothen the curve, used as parameter for auto finding integration points</td>
#       <td id="T_f9fa5_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_f9fa5_row8_col3" class="data row8 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_f9fa5_level0_row9" class="row_heading level0 row9" >t_integration_baseline__timestamp</th>
#       <td id="T_f9fa5_row9_col0" class="data row9 col0" >hte_processor</td>
#       <td id="T_f9fa5_row9_col1" class="data row9 col1" >timestamp of chosen baseline point (redundant information, but difficult to query timestamp for ec_datasets from id_data_integration...)</td>
#       <td id="T_f9fa5_row9_col2" class="data row9 col2" >None</td>
#       <td id="T_f9fa5_row9_col3" class="data row9 col3" >datetime</td>
#     </tr>
#     <tr>
#       <th id="T_f9fa5_level0_row10" class="row_heading level0 row10" >t_integration_begin__timestamp</th>
#       <td id="T_f9fa5_row10_col0" class="data row10 col0" >hte_processor</td>
#       <td id="T_f9fa5_row10_col1" class="data row10 col1" >timestamp of beginning of integration (redundant information, but difficult to query timestamp for ec_datasets from id_data_integration...)</td>
#       <td id="T_f9fa5_row10_col2" class="data row10 col2" >None</td>
#       <td id="T_f9fa5_row10_col3" class="data row10 col3" >datetime</td>
#     </tr>
#     <tr>
#       <th id="T_f9fa5_level0_row11" class="row_heading level0 row11" >t_integration_end__timestamp</th>
#       <td id="T_f9fa5_row11_col0" class="data row11 col0" >hte_processor</td>
#       <td id="T_f9fa5_row11_col1" class="data row11 col1" >timestamp of end of integration (redundant information, but difficult to query timestamp for ec_datasets from id_data_integration...)</td>
#       <td id="T_f9fa5_row11_col2" class="data row11 col2" >None</td>
#       <td id="T_f9fa5_row11_col3" class="data row11 col3" >datetime</td>
#     </tr>
#     <tr>
#       <th id="T_f9fa5_level0_row12" class="row_heading level0 row12" >y_offset</th>
#       <td id="T_f9fa5_row12_col0" class="data row12 col0" >hte_processor</td>
#       <td id="T_f9fa5_row12_col1" class="data row12 col1" >y offset between begin and end of integration</td>
#       <td id="T_f9fa5_row12_col2" class="data row
# ### counter_electrodes
#         BASE TABLE
#         Inventory list of avaiable counter electrode types. Different CEs of the same type are treated as one entry.
# <style type="text/css">
# #T_11680_row0_col0, #T_11680_row0_col1, #T_11680_row0_col2, #T_11680_row0_col3, #T_11680_row1_col0, #T_11680_row1_col1, #T_11680_row1_col2, #T_11680_row1_col3, #T_11680_row2_col0, #T_11680_row2_col1, #T_11680_row2_col2, #T_11680_row2_col3, #T_11680_row3_col0, #T_11680_row3_col1, #T_11680_row3_col2, #T_11680_row3_col3 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_11680">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11680_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_11680_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_11680_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_11680_level0_col3" class="col_heading level0 col3" >data_type</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11680_level0_row0" class="row_heading level0 row0" >manufacturer</th>
#       <td id="T_11680_row0_col0" class="data row0 col0" >user</td>
#       <td id="T_11680_row0_col1" class="data row0 col1" >Manufacturing company of the CE</td>
#       <td id="T_11680_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_11680_row0_col3" class="data row0 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_11680_level0_row1" class="row_heading level0 row1" >material</th>
#       <td id="T_11680_row1_col0" class="data row1 col0" >user</td>
#       <td id="T_11680_row1_col1" class="data row1 col1" >Material of the CE</td>
#       <td id="T_11680_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_11680_row1_col3" class="data row1 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_11680_level0_row2" class="row_heading level0 row2" >model</th>
#       <td id="T_11680_row2_col0" class="data row2 col0" >user</td>
#       <td id="T_11680_row2_col1" class="data row2 col1" >Model name of the CE given by the company or specifications needed for ordering the electrode (to be able to reorder)</td>
#       <td id="T_11680_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_11680_row2_col3" class="data row2 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_11680_level0_row3" class="row_heading level0 row3" >name_CE</th>
#       <td id="T_11680_row3_col0" class="data row3 col0" >user</td>
#       <td id="T_11680_row3_col1" class="data row3 col1" >user given name of th ecounter electrode. It has to be unique!</td>
#       <td id="T_11680_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_11680_row3_col3" class="data row3 col3" >varchar</td>
#     </tr>
#   </tbody>
# </table>
# ### data_compression
#         BASE TABLE
#         Contains compression data measured in compression experiments
# <style type="text/css">
# #T_f8060_row0_col0, #T_f8060_row0_col1, #T_f8060_row0_col2, #T_f8060_row0_col3, #T_f8060_row1_col0, #T_f8060_row1_col1, #T_f8060_row1_col2, #T_f8060_row1_col3, #T_f8060_row2_col0, #T_f8060_row2_col1, #T_f8060_row2_col2, #T_f8060_row2_col3, #T_f8060_row3_col0, #T_f8060_row3_col1, #T_f8060_row3_col2, #T_f8060_row3_col3, #T_f8060_row4_col0, #T_f8060_row4_col1, #T_f8060_row4_col2, #T_f8060_row4_col3, #T_f8060_row5_col0, #T_f8060_row5_col1, #T_f8060_row5_col2, #T_f8060_row5_col3 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_f8060">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8060_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_f8060_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_f8060_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_f8060_level0_col3" class="col_heading level0 col3" >data_type</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8060_level0_row0" class="row_heading level0 row0" >force__N</th>
#       <td id="T_f8060_row0_col0" class="data row0 col0" >labview_software</td>
#       <td id="T_f8060_row0_col1" class="data row0 col1" >measured force</td>
#       <td id="T_f8060_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_f8060_row0_col3" class="data row0 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_f8060_level0_row1" class="row_heading level0 row1" >id_data_compression</th>
#       <td id="T_f8060_row1_col0" class="data row1 col0" >labview_software</td>
#       <td id="T_f8060_row1_col1" class="data row1 col1" >index for the specific data point in a experiment used for the database internally. </td>
#       <td id="T_f8060_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_f8060_row1_col3" class="data row1 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_f8060_level0_row2" class="row_heading level0 row2" >id_exp_sfc</th>
#       <td id="T_f8060_row2_col0" class="data row2 col0" >labview_software</td>
#       <td id="T_f8060_row2_col1" class="data row2 col1" >index for each comprssion experiment connection to exp_sfc</td>
#       <td id="T_f8060_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_f8060_row2_col3" class="data row2 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_f8060_level0_row3" class="row_heading level0 row3" >t__s</th>
#       <td id="T_f8060_row3_col0" class="data row3 col0" >labview_software</td>
#       <td id="T_f8060_row3_col1" class="data row3 col1" >time in seconds since start of the experiment</td>
#       <td id="T_f8060_row3_col2" class="data row3 col2" >$t$ / s</td>
#       <td id="T_f8060_row3_col3" class="data row3 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_f8060_level0_row4" class="row_heading level0 row4" >Timestamp</th>
#       <td id="T_f8060_row4_col0" class="data row4 col0" >labview_software</td>
#       <td id="T_f8060_row4_col1" class="data row4 col1" >timestamp of the datapoint</td>
#       <td id="T_f8060_row4_col2" class="data row4 col2" >Timestamp</td>
#       <td id="T_f8060_row4_col3" class="data row4 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_f8060_level0_row5" class="row_heading level0 row5" >z_pos__mm</th>
#       <td id="T_f8060_row5_col0" class="data row5 col0" >labview_software</td>
#       <td id="T_f8060_row5_col1" class="data row5 col1" >position of the z linear axis</td>
#       <td id="T_f8060_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_f8060_row5_col3" class="data row5 col3" >float</td>
#     </tr>
#   </tbody>
# </table>
# ### data_ec
#         BASE TABLE
#         Data table of all electrochemal direct current experiments identified by id_exp_ec
# <style type="text/css">
# #T_2c9bb_row0_col0, #T_2c9bb_row0_col1, #T_2c9bb_row0_col2, #T_2c9bb_row0_col3, #T_2c9bb_row1_col0, #T_2c9bb_row1_col1, #T_2c9bb_row1_col2, #T_2c9bb_row1_col3, #T_2c9bb_row2_col0, #T_2c9bb_row2_col1, #T_2c9bb_row2_col2, #T_2c9bb_row2_col3, #T_2c9bb_row3_col0, #T_2c9bb_row3_col1, #T_2c9bb_row3_col2, #T_2c9bb_row3_col3, #T_2c9bb_row4_col0, #T_2c9bb_row4_col1, #T_2c9bb_row4_col2, #T_2c9bb_row4_col3, #T_2c9bb_row5_col0, #T_2c9bb_row5_col1, #T_2c9bb_row5_col2, #T_2c9bb_row5_col3, #T_2c9bb_row6_col0, #T_2c9bb_row6_col1, #T_2c9bb_row6_col2, #T_2c9bb_row6_col3, #T_2c9bb_row7_col0, #T_2c9bb_row7_col1, #T_2c9bb_row7_col2, #T_2c9bb_row7_col3, #T_2c9bb_row8_col0, #T_2c9bb_row8_col1, #T_2c9bb_row8_col2, #T_2c9bb_row8_col3, #T_2c9bb_row9_col0, #T_2c9bb_row9_col1, #T_2c9bb_row9_col2, #T_2c9bb_row9_col3 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_2c9bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2c9bb_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_2c9bb_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_2c9bb_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_2c9bb_level0_col3" class="col_heading level0 col3" >data_type</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2c9bb_level0_row0" class="row_heading level0 row0" >cycle</th>
#       <td id="T_2c9bb_row0_col0" class="data row0 col0" >labview_software</td>
#       <td id="T_2c9bb_row0_col1" class="data row0 col1" >Number of cycle for cyclic methods</td>
#       <td id="T_2c9bb_row0_col2" class="data row0 col2" >cycle</td>
#       <td id="T_2c9bb_row0_col3" class="data row0 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_2c9bb_level0_row1" class="row_heading level0 row1" >Delta_E_WE_uncomp__V</th>
#       <td id="T_2c9bb_row1_col0" class="data row1 col0" >labview_software</td>
#       <td id="T_2c9bb_row1_col1" class="data row1 col1" >difference of working electrode potential due to the insitu iR-drop compensation. Similar values can be derived by E_WE_raw__VvsRE*R_u__ohm*iR_corr_in_situ__percent/100</td>
#       <td id="T_2c9bb_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_2c9bb_row1_col3" class="data row1 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_2c9bb_level0_row2" class="row_heading level0 row2" >E_Signal__VvsRE</th>
#       <td id="T_2c9bb_row2_col0" class="data row2 col0" >labview_software</td>
#       <td id="T_2c9bb_row2_col1" class="data row2 col1" >potential value with which the potentiostat started the internal feedback loop for that measurement point (or something like this). Not important for normal usage. For further information study working principle of a potentiostat or consult gamry documentation.</td>
#       <td id="T_2c9bb_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_2c9bb_row2_col3" class="data row2 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_2c9bb_level0_row3" class="row_heading level0 row3" >E_WE_raw__VvsRE</th>
#       <td id="T_2c9bb_row3_col0" class="data row3 col0" >labview_software</td>
#       <td id="T_2c9bb_row3_col1" class="data row3 col1" >working electrode potential against the reference electrode potential, insitu iR drop corrected if R_u__ohm is given.</td>
#       <td id="T_2c9bb_row3_col2" class="data row3 col2" >$E_{\mathrm{raw}}$ / V vs. RE</td>
#       <td id="T_2c9bb_row3_col3" class="data row3 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_2c9bb_level0_row4" class="row_heading level0 row4" >I__A</th>
#       <td id="T_2c9bb_row4_col0" class="data row4 col0" >labview_software</td>
#       <td id="T_2c9bb_row4_col1" class="data row4 col1" >current flowing between working and counter electrode during that measurement point. Given in Amperes.</td>
#       <td id="T_2c9bb_row4_col2" class="data row4 col2" >$I$ / A</td>
#       <td id="T_2c9bb_row4_col3" class="data row4 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_2c9bb_level0_row5" class="row_heading level0 row5" >id_data_ec</th>
#       <td id="T_2c9bb_row5_col0" class="data row5 col0" >db_system</td>
#       <td id="T_2c9bb_row5_col1" class="data row5 col1" >index for the specific data point in a experiment used for the database internally. </td>
#       <td id="T_2c9bb_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_2c9bb_row5_col3" class="data row5 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_2c9bb_level0_row6" class="row_heading level0 row6" >id_exp_sfc</th>
#       <td id="T_2c9bb_row6_col0" class="data row6 col0" >labview_software</td>
#       <td id="T_2c9bb_row6_col1" class="data row6 col1" >connects experimental data (data_ec) to experiment parameters (exp_ec)</td>
#       <td id="T_2c9bb_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_2c9bb_row6_col3" class="data row6 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_2c9bb_level0_row7" class="row_heading level0 row7" >overload</th>
#       <td id="T_2c9bb_row7_col0" class="data row7 col0" >labview_software</td>
#       <td id="T_2c9bb_row7_col1" class="data row7 col1" >Overload error report from the potentiostat. Convert the given number to binary system, each 0 reflects an error occured during the measuerment. Possible errors: 'I History': 1,  'I OVLD': 2,  'CA History': 4, 'CA OVLD': 8, 'V OVLD': 16, 'Overrun': 32,''Heatsink': 64, 'Powersupply': 128, 'H settling': 256,  'S settling': 512,  'I ADC railed': 1024,  'V ADC railed': 2048,  'A ADC railed': 4096. There is an in-built function in the SFC Software to determine whether and which error occured during a measurment. For further help consult Jonas or Nico.</td>
#       <td id="T_2c9bb_row7_col2" class="data row7 col2" >None</td>
#       <td id="T_2c9bb_row7_col3" class="data row7 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_2c9bb_level0_row8" class="row_heading level0 row8" >t__s</th>
#       <td id="T_2c9bb_row8_col0" class="data row8 col0" >labview_software</td>
#       <td id="T_2c9bb_row8_col1" class="data row8 col1" >time in seconds since start of the experiment</td>
#       <td id="T_2c9bb_row8_col2" class="data row8 col2" >$t$ / s</td>
#       <td id="T_2c9bb_row8_col3" class="data row8 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_2c9bb_level0_row9" class="row_heading level0 row9" >Timestamp</th>
#       <td id="T_2c9bb_row9_col0" class="data row9 col0" >labview_software</td>
#       <td id="T_2c9bb_row9_col1" class="data row9 col1" >timestamp of the datapoint</td>
#       <td id="T_2c9bb_row9_col2" class="data row9 col2" >Timestamp</td>
#       <td id="T_2c9bb_row9_col3" class="data row9 col3" >varchar</td>
#     </tr>
#   </tbody>
# </table>
# ### data_ec_analysis
#         VIEW
#         VIEW
# <style type="text/css">
# #T_e042e_row0_col0, #T_e042e_row0_col1, #T_e042e_row0_col2, #T_e042e_row0_col3, #T_e042e_row1_col0, #T_e042e_row1_col1, #T_e042e_row1_col2, #T_e042e_row1_col3, #T_e042e_row2_col0, #T_e042e_row2_col1, #T_e042e_row2_col2, #T_e042e_row2_col3, #T_e042e_row3_col0, #T_e042e_row3_col1, #T_e042e_row3_col2, #T_e042e_row3_col3, #T_e042e_row4_col0, #T_e042e_row4_col1, #T_e042e_row4_col2, #T_e042e_row4_col3, #T_e042e_row5_col0, #T_e042e_row5_col1, #T_e042e_row5_col2, #T_e042e_row5_col3, #T_e042e_row6_col0, #T_e042e_row6_col1, #T_e042e_row6_col2, #T_e042e_row6_col3, #T_e042e_row7_col0, #T_e042e_row7_col1, #T_e042e_row7_col2, #T_e042e_row7_col3, #T_e042e_row8_col0, #T_e042e_row8_col1, #T_e042e_row8_col2, #T_e042e_row8_col3, #T_e042e_row9_col0, #T_e042e_row9_col1, #T_e042e_row9_col2, #T_e042e_row9_col3, #T_e042e_row10_col0, #T_e042e_row10_col1, #T_e042e_row10_col2, #T_e042e_row10_col3, #T_e042e_row11_col0, #T_e042e_row11_col1, #T_e042e_row11_col2, #T_e042e_row11_col3, #T_e042e_row12_col0, #T_e042e_row12_col1, #T_e042e_row12_col2, #T_e042e_row12_col3, #T_e042e_row13_col0, #T_e042e_row13_col1, #T_e042e_row13_col2, #T_e042e_row13_col3, #T_e042e_row14_col0, #T_e042e_row14_col1, #T_e042e_row14_col2, #T_e042e_row14_col3, #T_e042e_row15_col0, #T_e042e_row15_col1, #T_e042e_row15_col2, #T_e042e_row15_col3, #T_e042e_row16_col0, #T_e042e_row16_col1, #T_e042e_row16_col2, #T_e042e_row16_col3, #T_e042e_row17_col0, #T_e042e_row17_col1, #T_e042e_row17_col2, #T_e042e_row17_col3, #T_e042e_row18_col0, #T_e042e_row18_col1, #T_e042e_row18_col2, #T_e042e_row18_col3, #T_e042e_row19_col0, #T_e042e_row19_col1, #T_e042e_row19_col2, #T_e042e_row19_col3, #T_e042e_row20_col0, #T_e042e_row20_col1, #T_e042e_row20_col2, #T_e042e_row20_col3, #T_e042e_row21_col0, #T_e042e_row21_col1, #T_e042e_row21_col2, #T_e042e_row21_col3 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_e042e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e042e_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_e042e_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_e042e_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_e042e_level0_col3" class="col_heading level0 col3" >data_type</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e042e_level0_row0" class="row_heading level0 row0" >cycle</th>
#       <td id="T_e042e_row0_col0" class="data row0 col0" >labview_software</td>
#       <td id="T_e042e_row0_col1" class="data row0 col1" >Number of cycle for cyclic methods</td>
#       <td id="T_e042e_row0_col2" class="data row0 col2" >cycle</td>
#       <td id="T_e042e_row0_col3" class="data row0 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_e042e_level0_row1" class="row_heading level0 row1" >Delta_E_WE_uncomp__V</th>
#       <td id="T_e042e_row1_col0" class="data row1 col0" >labview_software</td>
#       <td id="T_e042e_row1_col1" class="data row1 col1" >difference of working electrode potential due to the insitu iR-drop compensation. Similar values can be derived by E_WE_raw__VvsRE*R_u__ohm*iR_corr_in_situ__percent/100</td>
#       <td id="T_e042e_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_e042e_row1_col3" class="data row1 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_e042e_level0_row2" class="row_heading level0 row2" >E_Signal__VvsRE</th>
#       <td id="T_e042e_row2_col0" class="data row2 col0" >labview_software</td>
#       <td id="T_e042e_row2_col1" class="data row2 col1" >potential value with which the potentiostat started the internal feedback loop for that measurement point (or something like this). Not important for normal usage. For further information study working principle of a potentiostat or consult gamry documentation.</td>
#       <td id="T_e042e_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_e042e_row2_col3" class="data row2 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_e042e_level0_row3" class="row_heading level0 row3" >E_WE__VvsRHE</th>
#       <td id="T_e042e_row3_col0" class="data row3 col0" >calculated</td>
#       <td id="T_e042e_row3_col1" class="data row3 col1" >potential corrected for RE to RHE using E_RE__VvsRHE and iR insitu and post-compensated  by exp_ec.R_u__ohm and exp_ec.iR_corr_in_situ__percent</td>
#       <td id="T_e042e_row3_col2" class="data row3 col2" >$E$ / V vs. RHE</td>
#       <td id="T_e042e_row3_col3" class="data row3 col3" >double</td>
#     </tr>
#     <tr>
#       <th id="T_e042e_level0_row4" class="row_heading level0 row4" >E_WE_raw__VvsRE</th>
#       <td id="T_e042e_row4_col0" class="data row4 col0" >labview_software</td>
#       <td id="T_e042e_row4_col1" class="data row4 col1" >working electrode potential against the reference electrode potential, insitu iR drop corrected if R_u__ohm is given.</td>
#       <td id="T_e042e_row4_col2" class="data row4 col2" >$E_{\mathrm{raw}}$ / V vs. RE</td>
#       <td id="T_e042e_row4_col3" class="data row4 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_e042e_level0_row5" class="row_heading level0 row5" >E_WE_raw__VvsRHE</th>
#       <td id="T_e042e_row5_col0" class="data row5 col0" >calculated</td>
#       <td id="T_e042e_row5_col1" class="data row5 col1" >potential corrected for RE to RHE using E_RE__VvsRHE, only iR-insitu-compensated if performed</td>
#       <td id="T_e042e_row5_col2" class="data row5 col2" >$E_{\mathrm{raw}}$ / V vs. RHE</td>
#       <td id="T_e042e_row5_col3" class="data row5 col3" >double</td>
#     </tr>
#     <tr>
#       <th id="T_e042e_level0_row6" class="row_heading level0 row6" >E_WE_uncompensated__VvsRHE</th>
#       <td id="T_e042e_row6_col0" class="data row6 col0" >calculated</td>
#       <td id="T_e042e_row6_col1" class="data row6 col1" >potential corrected for RE to RHE using E_RE__VvsRHE, subtracted insitu-iR compensation</td>
#       <td id="T_e042e_row6_col2" class="data row6 col2" >$E_{\mathrm{uncompensated}}$ / V vs. RHE</td>
#       <td id="T_e042e_row6_col3" class="data row6 col3" >double</td>
#     </tr>
#     <tr>
#       <th id="T_e042e_level0_row7" class="row_heading level0 row7" >I__A</th>
#       <td id="T_e042e_row7_col0" class="data row7 col0" >labview_software</td>
#       <td id="T_e042e_row7_col1" class="data row7 col1" >current flowing between working and counter electrode during that measurement point. Given in Amperes.</td>
#       <td id="T_e042e_row7_col2" class="data row7 col2" >$I$ / A</td>
#       <td id="T_e042e_row7_col3" class="data row7 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_e042e_level0_row8" class="row_heading level0 row8" >id_data_ec</th>
#       <td id="T_e042e_row8_col0" class="data row8 col0" >db_system</td>
#       <td id="T_e042e_row8_col1" class="data row8 col1" >index for the specific data point in a experiment used for the database internally. </td>
#       <td id="T_e042e_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_e042e_row8_col3" class="data row8 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_e042e_level0_row9" class="row_heading level0 row9" >id_exp_sfc</th>
#       <td id="T_e042e_row9_col0" class="data row9 col0" >labview_software</td>
#       <td id="T_e042e_row9_col1" class="data row9 col1" >connects experimental data (data_ec) to experiment parameters (exp_ec)</td>
#       <td id="T_e042e_row9_col2" class="data row9 col2" >None</td>
#       <td id="T_e042e_row9_col3" class="data row9 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_e042e_level0_row10" class="row_heading level0 row10" >j__mA_cm2geo_fc_bottom_cell_Aideal</th>
#       <td id="T_e042e_row10_col0" class="data row10 col0" >calculated</td>
#       <td id="T_e042e_row10_col1" class="data row10 col1" >geometric current density by assuming ideal cell opening of bottom cell being the limiting
# ### data_ec_polcurve
#         BASE TABLE
#         averaged data of polarization curve experiments
# <style type="text/css">
# #T_9b212_row0_col0, #T_9b212_row0_col1, #T_9b212_row0_col2, #T_9b212_row0_col3, #T_9b212_row1_col0, #T_9b212_row1_col1, #T_9b212_row1_col2, #T_9b212_row1_col3, #T_9b212_row2_col0, #T_9b212_row2_col1, #T_9b212_row2_col2, #T_9b212_row2_col3, #T_9b212_row3_col0, #T_9b212_row3_col1, #T_9b212_row3_col2, #T_9b212_row3_col3, #T_9b212_row4_col0, #T_9b212_row4_col1, #T_9b212_row4_col2, #T_9b212_row4_col3, #T_9b212_row5_col0, #T_9b212_row5_col1, #T_9b212_row5_col2, #T_9b212_row5_col3, #T_9b212_row6_col0, #T_9b212_row6_col1, #T_9b212_row6_col2, #T_9b212_row6_col3, #T_9b212_row7_col0, #T_9b212_row7_col1, #T_9b212_row7_col2, #T_9b212_row7_col3, #T_9b212_row8_col0, #T_9b212_row8_col1, #T_9b212_row8_col2, #T_9b212_row8_col3, #T_9b212_row9_col0, #T_9b212_row9_col1, #T_9b212_row9_col2, #T_9b212_row9_col3, #T_9b212_row10_col0, #T_9b212_row10_col1, #T_9b212_row10_col2, #T_9b212_row10_col3, #T_9b212_row11_col0, #T_9b212_row11_col1, #T_9b212_row11_col2, #T_9b212_row11_col3, #T_9b212_row12_col0, #T_9b212_row12_col1, #T_9b212_row12_col2, #T_9b212_row12_col3, #T_9b212_row13_col0, #T_9b212_row13_col1, #T_9b212_row13_col2, #T_9b212_row13_col3, #T_9b212_row14_col0, #T_9b212_row14_col1, #T_9b212_row14_col2, #T_9b212_row14_col3, #T_9b212_row15_col0, #T_9b212_row15_col1, #T_9b212_row15_col2, #T_9b212_row15_col3 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_9b212">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b212_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_9b212_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_9b212_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_9b212_level0_col3" class="col_heading level0 col3" >data_type</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="blank col0" >&nbsp;</th>
# ...
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d057e_level0_row0" class="row_heading level0 row0" >alias</th>
#       <td id="T_d057e_row0_col0" class="data row0 col0" >user</td>
#       <td id="T_d057e_row0_col1" class="data row0 col1" >alias name for the setup</td>
#       <td id="T_d057e_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_d057e_row0_col3" class="data row0 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_d057e_level0_row1" class="row_heading level0 row1" >feature</th>
#       <td id="T_d057e_row1_col0" class="data row1 col0" >user</td>
#       <td id="T_d057e_row1_col1" class="data row1 col1" >special feature of the setup</td>
#       <td id="T_d057e_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_d057e_row1_col3" class="data row1 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_d057e_level0_row2" class="row_heading level0 row2" >name_setup_sfc</th>
#       <td id="T_d057e_row2_col0" class="data row2 col0" >user</td>
#       <td id="T_d057e_row2_col1" class="data row2 col1" >Unique identifier of the SFC setup</td>
#       <td id="T_d057e_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_d057e_row2_col3" class="data row2 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_d057e_level0_row3" class="row_heading level0 row3" >type</th>
#       <td id="T_d057e_row3_col0" class="data row3 col0" >user</td>
#       <td id="T_d057e_row3_col1" class="data row3 col1" >type of the setup. So far only SFC setups are implemented. Please request feature for other setups ('RDE', 'MEA', 'GDE')</td>
#       <td id="T_d057e_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_d057e_row3_col3" class="data row3 col3" >enum</td>
#     </tr>
#   </tbody>
# </table>
# ### spots
#         BASE TABLE
#         Inventory list of all spots an samples for SFC measurements. coordinates relative to origin in upper left corner
# <style type="text/css">
# #T_0f045_row0_col0, #T_0f045_row0_col1, #T_0f045_row0_col2, #T_0f045_row0_col3, #T_0f045_row1_col0, #T_0f045_row1_col1, #T_0f045_row1_col2, #T_0f045_row1_col3, #T_0f045_row2_col0, #T_0f045_row2_col1, #T_0f045_row2_col2, #T_0f045_row2_col3, #T_0f045_row3_col0, #T_0f045_row3_col1, #T_0f045_row3_col2, #T_0f045_row3_col3, #T_0f045_row4_col0, #T_0f045_row4_col1, #T_0f045_row4_col2, #T_0f045_row4_col3, #T_0f045_row5_col0, #T_0f045_row5_col1, #T_0f045_row5_col2, #T_0f045_row5_col3, #T_0f045_row6_col0, #T_0f045_row6_col1, #T_0f045_row6_col2, #T_0f045_row6_col3, #T_0f045_row7_col0, #T_0f045_row7_col1, #T_0f045_row7_col2, #T_0f045_row7_col3, #T_0f045_row8_col0, #T_0f045_row8_col1, #T_0f045_row8_col2, #T_0f045_row8_col3, #T_0f045_row9_col0, #T_0f045_row9_col1, #T_0f045_row9_col2, #T_0f045_row9_col3 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_0f045">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f045_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_0f045_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_0f045_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_0f045_level0_col3" class="col_heading level0 col3" >data_type</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f045_level0_row0" class="row_heading level0 row0" >comment</th>
#       <td id="T_0f045_row0_col0" class="data row0 col0" >user</td>
#       <td id="T_0f045_row0_col1" class="data row0 col1" >user comment</td>
#       <td id="T_0f045_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_0f045_row0_col3" class="data row0 col3" >text</td>
#     </tr>
#     <tr>
#       <th id="T_0f045_level0_row1" class="row_heading level0 row1" >id_sample</th>
#       <td id="T_0f045_row1_col0" class="data row1 col0" >user</td>
#       <td id="T_0f045_row1_col1" class="data row1 col1" >Connect spot to sample</td>
#       <td id="T_0f045_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_0f045_row1_col3" class="data row1 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_0f045_level0_row2" class="row_heading level0 row2" >id_spot</th>
#       <td id="T_0f045_row2_col0" class="data row2 col0" >user</td>
#       <td id="T_0f045_row2_col1" class="data row2 col1" >Identifier for the spot on a sample. As it is a secondary index column auto_increment iks not possible using MySQL. So the id_spot has to be inserted by user!</td>
#       <td id="T_0f045_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_0f045_row2_col3" class="data row2 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_0f045_level0_row3" class="row_heading level0 row3" >m_CL__mg</th>
#       <td id="T_0f045_row3_col0" class="data row3 col0" >user</td>
#       <td id="T_0f045_row3_col1" class="data row3 col1" >mass of the catalyst layer, usually used for dropcasting where the absolute mass is known but the spot area varies</td>
#       <td id="T_0f045_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_0f045_row3_col3" class="data row3 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_0f045_level0_row4" class="row_heading level0 row4" >m_Decal__mg</th>
#       <td id="T_0f045_row4_col0" class="data row4 col0" >user</td>
#       <td id="T_0f045_row4_col1" class="data row4 col1" >mass of the decal sheet without catalyst layer after decal transfer)</td>
#       <td id="T_0f045_row4_col2" class="data row4 col2" >None</td>
#       <td id="T_0f045_row4_col3" class="data row4 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_0f045_level0_row5" class="row_heading level0 row5" >m_Decal+CL__mg</th>
#       <td id="T_0f045_row5_col0" class="data row5 col0" >user</td>
#       <td id="T_0f045_row5_col1" class="data row5 col1" >mass of the decal sheet with catalyst layer (before decal transfer)</td>
#       <td id="T_0f045_row5_col2" class="data row5 col2" >None</td>
#       <td id="T_0f045_row5_col3" class="data row5 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_0f045_level0_row6" class="row_heading level0 row6" >pos_x__mm</th>
#       <td id="T_0f045_row6_col0" class="data row6 col0" >user</td>
#       <td id="T_0f045_row6_col1" class="data row6 col1" >x-coordinate of the spot on the sample. Coordinates relative to origin in upper left corner.</td>
#       <td id="T_0f045_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_0f045_row6_col3" class="data row6 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_0f045_level0_row7" class="row_heading level0 row7" >pos_y__mm</th>
#       <td id="T_0f045_row7_col0" class="data row7 col0" >user</td>
#       <td id="T_0f045_row7_col1" class="data row7 col1" >y-coordinate of the spot on the sample. Coordinates relative to origin in upper left corner.</td>
#       <td id="T_0f045_row7_col2" class="data row7 col2" >None</td>
#       <td id="T_0f045_row7_col3" class="data row7 col3" >float</td>
#     </tr>
#     <tr>
#       <th id="T_0f045_level0_row8" class="row_heading level0 row8" >spot_size__mm2</th>
#       <td id="T_0f045_row8_col0" class="data row8 col0" >user</td>
#       <td id="T_0f045_row8_col1" class="data row8 col1" >Size of the spot if applicable for example for dropcasted samples. Can be used to determine the geometric electrode area. NULL for continuous samples, geometric electrode area in this case is rather defined by opening of the cell or sealing. Maximum 999 mm2 with precision 0.000001 mm2.</td>
#       <td id="T_0f045_row8_col2" class="data row8 col2" >None</td>
#       <td id="T_0f045_row8_col3" class="data row8 col3" >decimal</td>
#     </tr>
#     <tr>
#       <th id="T_0f045_level0_row9" class="row_heading level0 row9" >total_loading__mg_cm2</th>
#       <td id="T_0f045_row9_col0" class="data row9 col0" >user</td>
#       <td id="T_0f045_row9_col1" class="data row9 col1" >total loading in mg/cm² of the spot. If you want to store the loading of a specific element/material, specifiy the composition in sample_compositon (or spots_composition if composition deviates across sample). Maximum 10 with precision 0.0001</td>
#       <td id="T_0f045_row9_col2" class="data row9 col2" >None</td>
#       <td id="T_0f045_row9_col3" class="data row9 col3" >decimal</td>
#     </tr>
#   </tbody>
# </table>
# ### spots_auto
#         VIEW
#         VIEW
# <style type="text/css">
# #T_3eb2c_row0_col0, #T_3eb2c_row0_col1, #T_3eb2c_row0_col2, #T_3eb2c_row0_col3, #T_3eb2c_row1_col0, #T_3eb2c_row1_col1, #T_3eb2c_row1_col2, #T_3eb2c_row1_col3, #T_3eb2c_row2_col0, #T_3eb2c_row2_col1, #T_3eb2c_row2_col2, #T_3eb2c_row2_col3, #T_3eb2c_row3_col0, #T_3eb2c_row3_col1, #T_3eb2c_row3_col2, #T_3eb2c_row3_col3 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_3eb2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3eb2c_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_3eb2c_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_3eb2c_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_3eb2c_level0_col3" class="col_heading level0 col3" >data_type</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3eb2c_level0_row0" class="row_heading level0 row0" >id_sample</th>
#       <td id="T_3eb2c_row0_col0" class="data row0 col0" >user</td>
#       <td id="T_3eb2c_row0_col1" class="data row0 col1" >Connect spot to sample</td>
#       <td id="T_3eb2c_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_3eb2c_row0_col3" class="data row0 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_3eb2c_level0_row1" class="row_heading level0 row1" >id_spot</th>
#       <td id="T_3eb2c_row1_col0" class="data row1 col0" >user</td>
#       <td id="T_3eb2c_row1_col1" class="data row1 col1" >Identifier for the spot on a sample. As it is a secondary index column auto_increment iks not possible using MySQL. So the id_spot has to be inserted by user!</td>
#       <td id="T_3eb2c_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_3eb2c_row1_col3" class="data row1 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_3eb2c_level0_row2" class="row_heading level0 row2" >rel_x__mm</th>
#       <td id="T_3eb2c_row2_col0" class="data row2 col0" >calculated</td>
#       <td id="T_3eb2c_row2_col1" class="data row2 col1" >x position relative to spot 0,0, in mm</td>
#       <td id="T_3eb2c_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_3eb2c_row2_col3" class="data row2 col3" >double</td>
#     </tr>
#     <tr>
#       <th id="T_3eb2c_level0_row3" class="row_heading level0 row3" >rel_y__mm</th>
#       <td id="T_3eb2c_row3_col0" class="data row3 col0" >calculated</td>
#       <td id="T_3eb2c_row3_col1" class="data row3 col1" >y position relative to spot 0,0, in mm</td>
#       <td id="T_3eb2c_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_3eb2c_row3_col3" class="data row3 col3" >double</td>
#     </tr>
#   </tbody>
# </table>
# ### spots_composition
#         BASE TABLE
#         composition  of a spot on a sample is defined in weight percentage of the different materials/elements
# <style type="text/css">
# #T_1c5af_row0_col0, #T_1c5af_row0_col1, #T_1c5af_row0_col2, #T_1c5af_row0_col3, #T_1c5af_row1_col0, #T_1c5af_row1_col1, #T_1c5af_row1_col2, #T_1c5af_row1_col3, #T_1c5af_row2_col0, #T_1c5af_row2_col1, #T_1c5af_row2_col2, #T_1c5af_row2_col3, #T_1c5af_row3_col0, #T_1c5af_row3_col1, #T_1c5af_row3_col2, #T_1c5af_row3_col3 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_1c5af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c5af_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_1c5af_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_1c5af_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_1c5af_level0_col3" class="col_heading level0 col3" >data_type</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c5af_level0_row0" class="row_heading level0 row0" >id_sample</th>
#       <td id="T_1c5af_row0_col0" class="data row0 col0" >user</td>
#       <td id="T_1c5af_row0_col1" class="data row0 col1" >id of the sample</td>
#       <td id="T_1c5af_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_1c5af_row0_col3" class="data row0 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_1c5af_level0_row1" class="row_heading level0 row1" >id_spot</th>
#       <td id="T_1c5af_row1_col0" class="data row1 col0" >user</td>
#       <td id="T_1c5af_row1_col1" class="data row1 col1" >id of the spot on the given sample. If all spots have the same composition use table sample_composition.</td>
#       <td id="T_1c5af_row1_col2" class="data row1 col2" >None</td>
#       <td id="T_1c5af_row1_col3" class="data row1 col3" >int</td>
#     </tr>
#     <tr>
#       <th id="T_1c5af_level0_row2" class="row_heading level0 row2" >material</th>
#       <td id="T_1c5af_row2_col0" class="data row2 col0" >user</td>
#       <td id="T_1c5af_row2_col1" class="data row2 col1" >material can be either element, chemical compound or name of the material</td>
#       <td id="T_1c5af_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_1c5af_row2_col3" class="data row2 col3" >varchar</td>
#     </tr>
#     <tr>
#       <th id="T_1c5af_level0_row3" class="row_heading level0 row3" >wt_percent</th>
#       <td id="T_1c5af_row3_col0" class="data row3 col0" >user</td>
#       <td id="T_1c5af_row3_col1" class="data row3 col1" >weight percentage of the material in the spot. Maximum 100 with 0.00001 precision. An entry here will be preferred over the loading given in sample_composition.</td>
#       <td id="T_1c5af_row3_col2" class="data row3 col2" >None</td>
#       <td id="T_1c5af_row3_col3" class="data row3 col3" >decimal</td>
#     </tr>
#   </tbody>
# </table>
# ### users
#         BASE TABLE
#         Inventory list of user of this database. Used to define the user of an experiment or owner of a sample.
# <style type="text/css">
# #T_a9eeb_row0_col0, #T_a9eeb_row0_col1, #T_a9eeb_row0_col2, #T_a9eeb_row0_col3 {
#   text-align: left;
#   white-space: pre-wrap;
# }
# </style>
# <table id="T_a9eeb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9eeb_level0_col0" class="col_heading level0 col0" >name_inserter</th>
#       <th id="T_a9eeb_level0_col1" class="col_heading level0 col1" >comment</th>
#       <th id="T_a9eeb_level0_col2" class="col_heading level0 col2" >name_axislabel__latex</th>
#       <th id="T_a9eeb_level0_col3" class="col_heading level0 col3" >data_type</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >name_column</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9eeb_level0_row0" class="row_heading level0 row0" >name_user</th>
#       <td id="T_a9eeb_row0_col0" class="data row0 col0" >user</td>
#       <td id="T_a9eeb_row0_col1" class="data row0 col1" >Full name of the user; will be used for example to identify the owner of a sample</td>
#       <td id="T_a9eeb_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_a9eeb_row0_col3" class="data row0 col3" >varchar</td>
#     </tr>
#   </tbody>
# </table>
